# %% [markdown]
# ## Load Data

# %%
# csv_file = 'titanic.csv'

# csv_file = 'https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv'
# csv_file = 'https://raw.githubusercontent.com/rashakil-ds/Public-Datasets/main/anomaly.csv'
# csv_file = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/flights.csv'
# csv_file = 'https://raw.githubusercontent.com/plotly/datasets/master/gapminder2007.csv'
csv_file = 'titanic.csv'

# csv_file = fr'{csv_file}'

# %% [markdown]
# ## D-Tale Framework

# %%
import dtale
import pandas as pd

# Carrega seu DataFrame de dados
df = pd.read_csv(csv_file)

# Cria e abre o D-Tale no navegador
d = dtale.show(df, open_browser=True)
# Out:
# C:\Users\t203771\Downloads\samantha_ia-main\miniconda3\envs\jupyterlab\lib\site-packages\dtale\views.py:817: FutureWarning:
#
# ['Cabin', 'Embarked'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.

# %% [markdown]
# ## Y-Data Profiling Report

# %%
import pandas as pd
from ydata_profiling import ProfileReport # https://docs.profiling.ydata.ai/latest/
import webbrowser

df = pd.read_csv(csv_file)
profile = ProfileReport(df, title='Y-Data')
profile.to_file('Y-Data.html')
webbrowser.open('Y-Data.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# True

# %% [markdown]
# ## DataPrep Report

# %%
from dataprep.eda import create_report
import webbrowser

df = pd.read_csv(csv_file)
create_report(df, title='DataPrep').save('relatorio_dataprep.html')
webbrowser.open('relatorio_dataprep.html')
# Out:
#   0%|                                                                                         | 0/1423 [00:00<…
# C:\Users\t203771\Downloads\samantha_ia-main\miniconda3\envs\jupyterlab\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\t203771\Downloads\samantha_ia-main\miniconda3\envs\jupyterlab\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\t203771\Downloads\samantha_ia-main\miniconda3\envs\jupyterlab\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\t203771\Downloads\samantha_ia-main\miniconda3\envs\jupyterlab\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Report has been saved to relatorio_dataprep.html!
# True

# %% [markdown]
# ## SweetViz Report

# %%
#python
import pandas as pd
import sweetviz

# Carregue o arquivo CSV
df = pd.read_csv(csv_file)

# Crie um objeto Sweetviz
sv = sweetviz.analyze(df)

sv.show_html('SweetViz.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SweetViz.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# 2025-10-11 20:35:42,698 - INFO     - Executing shutdown...
# 2025-10-11 20:35:42,702 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer
# 2025-10-11 20:35:42,855 - ERROR    - weakly-referenced object no longer exists
# 2025-10-11 20:35:42,882 - ERROR    - weakly-referenced object no longer exists
# 2025-10-11 20:35:42,884 - ERROR    - weakly-referenced object no longer exists
# 2025-10-11 20:35:42,884 - ERROR    - weakly-referenced object no longer exists
